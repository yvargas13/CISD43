# %%
# Load the packages
import requests
#import BeautifulSoup package
from bs4 import BeautifulSoup
#import other libraries 
import pandas as pd

# %%
# Define a variable for the url of the site
our_site = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW"

# Making a get request and assign the result to a variable our_response
our_response = requests.get(our_site)

#Check that the response was processed correctly
our_response.status_code
# Out:
# 200

# %%
# Extracting the HTML
#assign a variable our_html to our_response content.
our_html = our_response.content

# Checking that the reply is indeed an HTML code by inspecting the first 200 symbols
our_html[:200]
# Out:
# b'<!doctype html><html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new '

# %%
our_soup = BeautifulSoup(our_html, "html.parser")
our_soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr-rw';
# ...

# %%
# Tables are marked with the 'table' tag in HTML
our_soup.find_all("table")
# Out:
# [<table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
#  </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
#  </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
#  </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
#  </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
#  </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
#  </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# ...

# %%
#Subsets the HTML to only get the HTML of our table needed
table = our_soup.find('table', class_ = 'a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated')
table
# Out:
# <table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# ...

# %%
#Gets all the column headers of our table
#create an empty list name it headers

headers = []
#lopp through all the header tags
#save the text in the table header tag after stripping any extra spaces as title
#append this title to the headers list

for i in table.find_all('th'):
    title = i.text.strip()
    headers.append(title)
    
print(headers)
# Out:
# ['Rank', 'Title', 'Worldwide Lifetime Gross', 'Domestic Lifetime Gross', 'Domestic %', 'Foreign Lifetime Gross', 'Foreign %', 'Year']

# %%
#Creates a dataframe using the column headers from our table
df = pd.DataFrame(columns = headers)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Title, Worldwide Lifetime Gross, Domestic Lifetime Gross, Domestic %, Foreign Lifetime Gross, Foreign %, Year]
# Index: []

# %%
for j in table.find_all('tr')[1:]:
    row_data = j.find_all('td')
    row = [tr.text for tr in row_data]
    length = len(df)
    df.loc[length] = row

# %%
#let us display the dataframe now
df
# Out:
#     Rank                                       Title Worldwide Lifetime Gross  \
# 0      1                                      Avatar           $2,847,397,339
# 1      2                           Avengers: Endgame           $2,797,501,328
# 2      3                                     Titanic           $2,201,647,264
# 3      4  Star Wars: Episode VII - The Force Awakens           $2,069,521,700
# 4      5                      Avengers: Infinity War           $2,048,359,754
# ..   ...                                         ...                      ...
# 195  196                           X-Men: Apocalypse             $543,934,105
# 196  197          Sherlock Holmes: A Game of Shadows             $543,848,418
# 197  198                               Despicable Me             $543,157,985
# 198  199                                  Cinderella             $542,358,331
# 199  200                                  Madagascar             $542,063,846
#
# ...

# %%
#let's see the info of our dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      200 non-null    object
#  1   Title                     200 non-null    object
#  2   Worldwide Lifetime Gross  200 non-null    object
#  3   Domestic Lifetime Gross   200 non-null    object
#  4   Domestic %                200 non-null    object
#  5   Foreign Lifetime Gross    200 non-null    object
#  6   Foreign %                 200 non-null    object
#  7   Year                      200 non-null    object
# dtypes: object(8)
# memory usage: 14.1+ KB

# %%
df['Domestic Percent'] = df['Domestic %'].apply(lambda x:x.replace("%", ""))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      200 non-null    object
#  1   Title                     200 non-null    object
#  2   Worldwide Lifetime Gross  200 non-null    object
#  3   Domestic Lifetime Gross   200 non-null    object
#  4   Domestic %                200 non-null    object
#  5   Foreign Lifetime Gross    200 non-null    object
#  6   Foreign %                 200 non-null    object
#  7   Year                      200 non-null    object
#  8   Domestic Percent          200 non-null    object
# dtypes: object(9)
# memory usage: 15.6+ KB

# %%
less_object = []
def find_1(x): 
    if isinstance(x, int) or isinstance(x, float): 
        pass
    else: 
        a = df[df["Domestic Percent"] == x].index
        less_object.append(a)
        
df["Domestic Percent"].apply(find_1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 195    None
# 196    None
# 197    None
# 198    None
# 199    None
# Name: Domestic Percent, Length: 200, dtype: object

# %%
less_object
# Out:
# [Int64Index([0], dtype='int64'),
#  Int64Index([1], dtype='int64'),
#  Int64Index([2], dtype='int64'),
#  Int64Index([3], dtype='int64'),
#  Int64Index([4, 159], dtype='int64'),
#  Int64Index([5, 173], dtype='int64'),
#  Int64Index([6], dtype='int64'),
#  Int64Index([7, 11], dtype='int64'),
#  Int64Index([8], dtype='int64'),
#  Int64Index([9], dtype='int64'),
#  Int64Index([10], dtype='int64'),
#  Int64Index([7, 11], dtype='int64'),
#  Int64Index([12], dtype='int64'),
#  Int64Index([13], dtype='int64'),
#  Int64Index([14], dtype='int64'),
#  Int64Index([15, 174], dtype='int64'),
#  Int64Index([16, 46], dtype='int64'),
#  Int64Index([17], dtype='int64'),
#  Int64Index([18], dtype='int64'),
#  Int64Index([19], dtype='int64'),
#  Int64Index([20], dtype='int64'),
#  Int64Index([21, 111], dtype='int64'),
#  Int64Index([22], dtype='int64'),
#  Int64Index([23, 182], dtype='int64'),
#  Int64Index([24], dtype='int64'),
#  Int64Index([25], dtype='int64'),
# ...

# %%
df['Foreign Percent'] = df['Foreign %'].apply(lambda x:float(x.replace("%", "")))
df
# Out:
#     Rank                                       Title Worldwide Lifetime Gross  \
# 0      1                                      Avatar           $2,847,397,339
# 1      2                           Avengers: Endgame           $2,797,501,328
# 2      3                                     Titanic           $2,201,647,264
# 3      4  Star Wars: Episode VII - The Force Awakens           $2,069,521,700
# 4      5                      Avengers: Infinity War           $2,048,359,754
# ..   ...                                         ...                      ...
# 195  196                           X-Men: Apocalypse             $543,934,105
# 196  197          Sherlock Holmes: A Game of Shadows             $543,848,418
# 197  198                               Despicable Me             $543,157,985
# 198  199                                  Cinderella             $542,358,331
# 199  200                                  Madagascar             $542,063,846
#
# ...

# %%
#Multiple errors for attempting to coonvert Domestic Percetn column from objects to float
#I have found that the errors are rooted from the notation of that some films earned little to no domestically 

#locate the films that earned less than "<0.1" in the Domestic Percent column
df.loc[df["Domestic Percent"] == "<0.1"]
# Out:
#     Rank                        Title Worldwide Lifetime Gross  \
# 62    63  The Battle at Lake Changjin             $902,540,935
# 155  156            Water Gate Bridge             $626,203,271
#
#     Domestic Lifetime Gross Domestic % Foreign Lifetime Gross Foreign %  Year  \
# 62                 $342,411      <0.1%           $902,198,524      100%  2021
# 155                $117,294      <0.1%           $626,085,977      100%  2022
#
#     Domestic Percent  Foreign Percent
# 62              <0.1            100.0
# 155             <0.1            100.0

# %%
df['Domestic Percent'] = df['Domestic %'].apply(lambda x:x.replace("<", ""))
df['Domestic Percent'].loc[df.index[62]]
# Out:
# '0.1%'

# %%
df['Domestic Percent'] = df['Domestic %'].apply(lambda x:x.replace("%", ""))
df['Domestic Percent'].loc[df.index[62]]
# Out:
# '<0.1'

# %%
df['Domestic Percent'] = df['Domestic Percent'].replace(["<0.1%"], 0)
# Out:
# 0

# %%
df.loc[df["Domestic Percent"] == 0]
# Out:
#     Rank                        Title Worldwide Lifetime Gross  \
# 62    63  The Battle at Lake Changjin             $902,540,935
# 155  156            Water Gate Bridge             $626,203,271
#
#     Domestic Lifetime Gross Domestic % Foreign Lifetime Gross Foreign %  Year  \
# 62                 $342,411      <0.1%           $902,198,524      100%  2021
# 155                $117,294      <0.1%           $626,085,977      100%  2022
#
#     Domestic Percent  Foreign Percent
# 62                 0            100.0
# 155                0            100.0

# %%
# [row, column]
df.iloc[62,:]
# Out:
# Rank                                                 63
# Title                       The Battle at Lake Changjin
# Worldwide Lifetime Gross                   $902,540,935
# Domestic Lifetime Gross                        $342,411
# Domestic %                                        <0.1%
# Foreign Lifetime Gross                     $902,198,524
# Foreign %                                          100%
# Year                                               2021
# Domestic Percent                                      0
# Foreign Percent                                   100.0
# Name: 62, dtype: object

# %%
def NegNumFunc(x):
    try: 
        a =

# %%
df['Domestic Percent'] = df['Domestic Percent'].apply(lambda x:float(x))
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12784/3724127548.py in <module>
# ----> 1 df['Domestic Percent'] = df['Domestic Percent'].apply(lambda x:float(x))
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      200 non-null    object
#  1   Title                     200 non-null    object
#  2   Worldwide Lifetime Gross  200 non-null    object
#  3   Domestic Lifetime Gross   200 non-null    object
#  4   Domestic %                200 non-null    object
#  5   Foreign Lifetime Gross    200 non-null    object
#  6   Foreign %                 200 non-null    object
#  7   Year                      200 non-null    object
#  8   Domestic Percent          200 non-null    object
#  9   Foreign Percent           200 non-null    float64
# dtypes: float64(1), object(9)
# memory usage: 25.3+ KB

# %%
df['Domestic %'] = df['Domestic %'].astype(float, errors = 'raise')
df['Foreign %'] = df['Foreign %'].astype(float, errors = 'raise')
df['Worldwide Lifetime Gross'] = df['WorldWide Lifetime Gross'].astype(float, errors = 'raise')
df['Foreign Lifetime Gross'] = df['Foreign Lifetime Gross'].astype(float, errors = 'raise')
df['Year'] = df['Year'].astype(int, errors = 'raise')

print(df.info())
